# %% [markdown]
# # Vegetarian and Vegan Restaurants in the United States

# %% [markdown]
# ### A Project by Leonela Aguilar

# %% [markdown]
# ### Professor Benjamin
# ### DH 140, Winter 2022

# %% [markdown]
# #### Introduction

# %% [markdown]
# Veganism and vegetarianism is the practice of abstaining from the consumption and diet of animal products and is an associated philosophy that rejects the inferiority of animals. An individual who follows the diet or philosophy is known as a vegan or vegetarian. Whether motivated by health, environmental, or ethical reasons, the number of vegans/vegetarians in the United States and everywhere around the world is steadily increasing. Regardless of an individual's choice to be vegan/vegetarian, the increasing accessibilty of these diet options in restaurants showcases that the plant based diet is not simply a trend. The plant based diet is a lifestyle that caters to the individual's personal choices.

# %% [markdown]
# The percentage of Americans following the plant diet demonstrates that veganism/vegetarianism is more than just a trend. In 2017, the number of vegans hovered around seven million Americans, [Veganism on the Rise](https://go.gale.com/ps/i.do?id=GALE%7CA512288950&sid=googleScholar&v=2.1&it=r&linkaccess=abs&issn=09753966&p=AONE&sw=w&userGroupName=anon%7E3bdadb0f). As of today, plant-based population has reached new numbers. People have begun changing their perspectives on the meat industry and how it affects animals, people, and the planet. Businesses and corporations in the United States are making vegan and vegetarian products more accessible than ever. Evidently, vegan/vegetarian foods are appearing on supermarkets shelves and in restaurants, [Veganism: Theory of Planned Behaviour, Ethical Concerns and the Moderating Role of Catalytic Experiences](https://www.sciencedirect.com/science/article/pii/S0969698922000455?casa_token=kR0cAfn4JyIAAAAA:JITO1yUe-3QydEH-T6DkOY00vsMlm-k6a92jixNIeI_LhU5KNTzbk3xU_qhqumufWzxraTe57sk). Overall, the plant-based food industry is booming as thousands of new menu options drop every year in U.S restaurants. By analyzing the veganism/vegetarianism statistics of the year 2018, we can fully witness the extent of how this plant-based food culture has influenced the 21st century society and how it will continue to do so for decades to come.

# %% [markdown]
# #### Why is veganism/vegetarianism important ?

# %% [markdown]
# As a vegan myself, accessibility to vegan foods is both challenging and tricky. When traveling, some areas have little to no vegan/vegetarian options for individuals following a plant based diet. This challenge has inspired me to conduct research on the geographic and statistical data relating to plant based diets in the United States.  I believe we should bring more awareness about the vegan/vegetarian lifestyle and its potential animal, environmental, and health benefits. In addition, the rising popularity of veganism/vegetarianism goes hand in hand with the increasing number of products offered for people with food allergies or other dietary restrictions. For example, several Americans are lactose intolerant which accounts for the rise of plant-based milk consumption. This rise in selective eating habits (due to allergies or diet trends) has created a massive demand and change within the food market. In general, veganism/vegetarianism is becoming a popular lifestyle in the United States.

# %% [markdown]
# #### Research and Analysis

# %% [markdown]
# The following sample data contains a list of 10,000 restaurants that serve vegetarian or vegan food options in the United States.The list gives a general over review of vegan and vegetarian menu items based on Datafiniti’s Business Database.The original includes over 18,000 restaurants but will be analyzing a sample of 10,000. Each restaurant is defined by  vegan or vegetarian diet. The full data set is available at [Kaggle Vegetarian and Vegan Data](https://www.kaggle.com/datafiniti/vegetarian-vegan-restaurants).

# %% [markdown]
# For this project I want to analyze the following research questions :
#
#     How many restaurants in each metro area offers vegetarian/veg options?
#     Which metros among the US have the most and least vegetarian restaurants?
#     How many restaurants in each metro area offers vegan options?
#     Which cuisines are served the most at vegetarian restaurants?
#
# Overall my goal is to address how has the accesibility of vegan foods contribute to the popularity of the vegan lifestyle in the United States.The dataset includes address, city, state, business name, business categories, menu data, phone numbers, and more.From this data we can see which cities offer the most or least options and what variety is served.

# %% [markdown]
# The source I intend to use for this project is Kaggle which is a data science website available to the public. The specific data set I am observing is Kaggle's Vegan & Vegetarian Restaurants in the U.S. This data includes categorical and numerical information. In order to capture significant patterns relevant to vegetarian/vegan menu items, my visualizations will analyze statistical data. By creating geographical maps, I can pinpoint the popularity of veganism/vegetarianism among certain communities. No doubt, vegetarian and vegan food availability affects plant based consumption patterns. I hope to create visuals to showcase vegan trends in certain areas and run comparisons to bring about awareness of this lifestyle.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Let's begin exploring the data using the following csv file from Kaggle

# %%
df = pd.read_csv('Vegetarian_and_Vegan_Restaurants.csv')

# %%
df
# Out:
#                         id             dateAdded           dateUpdated  \
# 0     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 1     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 2     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 3     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 4     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# ...                    ...                   ...                   ...
# 9995  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9996  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9997  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9998  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9999  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
#
#                  address                                         categories  \
# ...

# %% [markdown]
# Here I am viewing the data

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Let's take a look at the first five rows

# %%
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 1  AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 2  AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 3  AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 4  AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
#
#               address                                         categories  \
# 0  1045 San Pablo Ave  Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# 1  1045 San Pablo Ave  Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# 2  1045 San Pablo Ave  Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# 3  1045 San Pablo Ave  Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# 4  1045 San Pablo Ave  Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
#
#                primaryCategories    city claimed country  \
# ...

# %% [markdown]
# ## The types of data we are working with :

# %%
df.dtypes
# Out:
# id                          object
# dateAdded                   object
# dateUpdated                 object
# address                     object
# categories                  object
# primaryCategories           object
# city                        object
# claimed                     object
# country                     object
# cuisines                    object
# descriptions.dateSeen      float64
# descriptions.sourceURLs    float64
# descriptions.value         float64
# facebookPageURL             object
# features.key               float64
# features.value             float64
# hours.day                  float64
# hours.dept                 float64
# hours.hour                 float64
# imageURLs                   object
# isClosed                    object
# keys                        object
# languagesSpoken            float64
# latitude                   float64
# longitude                  float64
# menuPageURL                 object
# menus.amountMax            float64
# ...

# %% [markdown]
# Based on the categories/columns from the cvs file.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       10000 non-null  object
#  1   dateAdded                10000 non-null  object
#  2   dateUpdated              10000 non-null  object
#  3   address                  10000 non-null  object
#  4   categories               10000 non-null  object
#  5   primaryCategories        10000 non-null  object
#  6   city                     10000 non-null  object
#  7   claimed                  689 non-null    object
#  8   country                  10000 non-null  object
#  9   cuisines                 10000 non-null  object
#  10  descriptions.dateSeen    0 non-null      float64
#  11  descriptions.sourceURLs  0 non-null      float64
#  12  descriptions.value       0 non-null      float64
#  13  facebookPageURL          937 non-null    object
# ...

# %% [markdown]
# ## The shape command tells us the amount of data we are working with

# %%
df.shape
# Out:
# (10000, 47)

# %% [markdown]
# ## Let's take a look at our list of organized columns

# %%
df.columns
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'address', 'categories',
#        'primaryCategories', 'city', 'claimed', 'country', 'cuisines',
#        'descriptions.dateSeen', 'descriptions.sourceURLs',
#        'descriptions.value', 'facebookPageURL', 'features.key',
#        'features.value', 'hours.day', 'hours.dept', 'hours.hour', 'imageURLs',
#        'isClosed', 'keys', 'languagesSpoken', 'latitude', 'longitude',
#        'menuPageURL', 'menus.amountMax', 'menus.amountMin', 'menus.category',
#        'menus.currency', 'menus.dateSeen', 'menus.description', 'menus.name',
#        'menus.sourceURLs', 'name', 'paymentTypes', 'phones', 'postalCode',
#        'priceRangeCurrency', 'priceRangeMin', 'priceRangeMax', 'province',
#        'sic', 'sourceURLs', 'twitter', 'websites', 'yearOpened'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['id',
#  'dateAdded',
#  'dateUpdated',
#  'address',
#  'categories',
#  'primaryCategories',
#  'city',
#  'claimed',
#  'country',
#  'cuisines',
#  'descriptions.dateSeen',
#  'descriptions.sourceURLs',
#  'descriptions.value',
#  'facebookPageURL',
#  'features.key',
#  'features.value',
#  'hours.day',
#  'hours.dept',
#  'hours.hour',
#  'imageURLs',
#  'isClosed',
#  'keys',
#  'languagesSpoken',
#  'latitude',
#  'longitude',
#  'menuPageURL',
#  'menus.amountMax',
#  'menus.amountMin',
#  'menus.category',
#  'menus.currency',
#  'menus.dateSeen',
#  'menus.description',
#  'menus.name',
#  'menus.sourceURLs',
#  'name',
#  'paymentTypes',
#  'phones',
#  'postalCode',
#  'priceRangeCurrency',
#  'priceRangeMin',
#  'priceRangeMax',
#  'province',
#  'sic',
#  'sourceURLs',
#  'twitter',
#  'websites',
#  'yearOpened']

# %%
df
# Out:
#                         id             dateAdded           dateUpdated  \
# 0     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 1     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 2     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 3     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 4     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# ...                    ...                   ...                   ...
# 9995  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9996  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9997  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9998  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9999  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
#
#                  address                                         categories  \
# ...

# %% [markdown]
# ## Let's take a clear look at the categories of vegan/vegetarian foods we are working with

# %%
df['categories']
# Out:
# 0       Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# 1       Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# 2       Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# 3       Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# 4       Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
#                               ...
# 9995    Vegetarian / Vegan Restaurant,Restaurant,Medit...
# 9996    Vegetarian / Vegan Restaurant,Restaurant,Medit...
# 9997    Vegetarian / Vegan Restaurant,Restaurant,Medit...
# 9998    Vegetarian / Vegan Restaurant,Restaurant,Medit...
# 9999    Vegetarian / Vegan Restaurant,Restaurant,Medit...
# Name: categories, Length: 10000, dtype: object

# %%
pd.unique(df['categories'])
# Out:
# array(['Restaurant,Asian/Pacific,Cafe,Vegetarian / Vegan Restaurant,Vegetarian,Vegetarian Vegan Restaurant,Caf,Thai',
#        'Indian Restaurant,Restaurant,Caterers,Food Dining,Catering,Vegetarian Restaurants,Restaurants,Indian Restaurants,Food & Dining,Middle Eastern Restaurants',
#        'Restaurant,Juice Bars,Smoothies and Juices,Vegetarian,Beverages Retail,Beverages,Healthy',
#        'Restaurant,Coffee Shops,Beverages Wholesale & Manufacturers,Local/Organic,Vegan Restaurants,Smoothies and Juices,Vegetarian / Vegan Restaurant,Vegetarian,Juice Bar,Vegetarian Restaurants,Healthy,Restaurants',
#        'Italian Restaurant,Restaurant,Take Out,Italian,Deli & Sandwich,Vegetarian,Seafood,Government Contractors,Italian Foods,Italian Restaurant Uptown-Galleria,Family Restaurants,Restaurants',
#        'Restaurant,Sushi,Kosher,Vegan',
#        'Restaurant,Desserts,Bakery and Pastries,Vegan',
# ...

# %% [markdown]
# ##### We have a variety of options such as Tex-Mex, Asian restaurants, etc

# %% [markdown]
# ## Now let's take a look at the cities we are working with specifically

# %%
df['city']
# Out:
# 0        Albany
# 1        Albany
# 2        Albany
# 3        Albany
# 4        Albany
#          ...
# 9995    Phoenix
# 9996    Phoenix
# 9997    Phoenix
# 9998    Phoenix
# 9999    Phoenix
# Name: city, Length: 10000, dtype: object

# %%
pd.unique(df['city'])
# Out:
# array(['Albany', 'San Diego', 'New York', 'Houston', 'Brooklyn',
#        'Long Island City', 'Astoria', 'Jackson Heights', 'Torrance',
#        'San Francisco', 'Los Angeles', 'Concord', 'Chicago',
#        'College Point', 'Bellerose', 'Glen Oaks', 'Austin', 'Phoenix',
#        'Canoga Park', 'Tempe', 'Richmond', 'Newport Beach',
#        'Salt Lake City', 'Encino', 'Hollywood', 'Escondido', 'Vienna',
#        'Westmont', 'Boston', 'Pittsburgh', 'Woodside', 'Santa Fe',
#        'Miami', 'Beverly Hills', 'Diamond Bar', 'Berkeley', 'Champaign',
#        'Evanston', 'South Richmond Hill', 'Wellesley Hills', 'Charlotte',
#        'Penfield', 'Warren', 'Napa', 'Redmond', 'Glendale',
#        'Overland Park', 'Atlanta', 'Santa Clara', 'Nashville', 'Carson',
#        'Raleigh', 'Waltham', 'Seattle', 'Asbury Park', 'Cambridge',
#        'Tahoe City', 'Portland', 'Dallas', 'San Jose', 'Tucson', 'Neenah',
#        'Arlington', 'Minneapolis', 'Kew Gardens', 'Cary', 'Philadelphia',
# ...

# %% [markdown]
# ##### These are the list of cities we are working with

# %% [markdown]
# ## Now let's look at the cuisines

# %%
df['cuisines']
# Out:
# 0                         Thai,Asian/Pacific,Vegetarian
# 1                         Thai,Asian/Pacific,Vegetarian
# 2                         Thai,Asian/Pacific,Vegetarian
# 3                         Thai,Asian/Pacific,Vegetarian
# 4                         Thai,Asian/Pacific,Vegetarian
#                              ...
# 9995    Mediterranean,Vegetarian,Persian,Middle Eastern
# 9996    Mediterranean,Vegetarian,Persian,Middle Eastern
# 9997    Mediterranean,Vegetarian,Persian,Middle Eastern
# 9998    Mediterranean,Vegetarian,Persian,Middle Eastern
# 9999    Mediterranean,Vegetarian,Persian,Middle Eastern
# Name: cuisines, Length: 10000, dtype: object

# %%
pd.unique(df['cuisines'])
# Out:
# array(['Thai,Asian/Pacific,Vegetarian', 'Vegetarian,Indian',
#        'Smoothies and Juices,Vegetarian,Healthy',
#        'Local/Organic,Vegan Restaurants,Smoothies and Juices,Vegetarian,Healthy',
#        'Seafood,Italian,Vegetarian,Deli and Sandwich',
#        'Sushi,Kosher,Vegan', 'Desserts,Bakery and Pastries,Vegan',
#        'American (New),Vegetarian,Coffee and Tea,Health Food,Vegan',
#        'Vegetarian,Coffee and Tea,Bakery,Desserts,Bakery and Pastries,Vegan',
#        'Local/Organic,Vegetarian,Coffee and Tea,Healthy,Vegan',
#        'Vegetarian,Dim Sum,Chinese', 'Vegetarian,Coffee and Tea',
#        'Vegetarian,Sandwiches', 'Vegetarian,Greek',
#        'Southeast Asian,Vegetarian,Korean', 'Vegetarian,Thai',
#        'Vegetarian,Salads', 'Vegetarian,Chinese',
#        'Vegetarian,Kosher,Sandwiches,Kosher, Vegetarian-Friendly, Sandwiches',
#        'British (Modern),Vegetarian', 'Deli Food,Vegetarian,Indian',
#        'Middle Eastern,Vegetarian',
# ...

# %% [markdown]
# ## Let's look at the cities

# %%
df['province']
# Out:
# 0       CA
# 1       CA
# 2       CA
# 3       CA
# 4       CA
#         ..
# 9995    AZ
# 9996    AZ
# 9997    AZ
# 9998    AZ
# 9999    AZ
# Name: province, Length: 10000, dtype: object

# %%
pd.unique(df['province'])
# Out:
# array(['CA', 'NY', 'TX', 'NH', 'IL', 'AZ', 'VA', 'UT', 'FL', 'MA', 'PA',
#        'NM', 'NC', 'MI', 'WA', 'KS', 'GA', 'TN', 'NJ', 'OR', 'WI', 'MN',
#        'HI', 'ME', 'NV'], dtype=object)

# %%
df['menus.category']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 9995    NaN
# 9996    NaN
# 9997    NaN
# 9998    NaN
# 9999    NaN
# Name: menus.category, Length: 10000, dtype: object

# %% [markdown]
# ## Finally let's take a look at the menu's and types of food served at these restaurants

# %%
pd.unique(df['menus.category'])
# Out:
# array([nan, 'Side Orders', 'Appetizers', 'Traditional Tandoori Breads',
#        'Tandoori Sizzlers', 'Vegetarian Entrees', 'Indian Desserts',
#        'Combination Dinner For Two', 'Basmati Rice Specialties',
#        'Acai Bowls', 'Fresh Juices', 'Smoothies', 'RX Juices',
#        'Quick Shots', 'Vegan Soups', 'Side Salads', 'Cold Pressed Juice',
#        'Baked Goods', 'Snacks', 'Breakfast', 'Old School Juices',
#        'Juice Cleanses', 'All Day Breakfast', 'Desserts', 'Sandwiches',
#        'Shots', 'Hot Drinks', 'Nut Milks', 'Other Cold Beverages', 'Soup',
#        'Smoothie Bowl', 'Salads', 'Omelettes', 'Frappuccino', 'Coffee',
#        'Wraps ampamp Paninis', 'Fresh Squeezed Juices', 'Pizza',
#        'Croissanwich', 'Iced Coffee', 'Milkshakes',
#        'Create Your Own Salads', 'Small Bites', 'Quinoa Bowls and Salad',
#        'Dessert', 'Fries', 'Bagels and Rolls', 'Breakfast All Day',
#        'Sides', 'Apps ampamp Shares', 'Add Ons', 'Bottled Beer', 'Beer',
# ...

# %% [markdown]
# ##### A favorite of mine ? Tofu !

# %% [markdown]
# ## Here I am cleaning and organizing the data of the categories, city, cuisines, provinces(states), and menu items because I believe they are relevant in pinpointing ceratin patterns.

# %%
df['categories'].value_counts()
# Out:
# Chinese Restaurant,Restaurant,Cocktails,Vegetarian,Dim Sum,Chinese,Dim Sum Restaurant                                                                                                                             375
# Restaurant,Vegetarian,Indian                                                                                                                                                                                      349
# Restaurant,Coffee Shops,Beverages Wholesale & Manufacturers,Local/Organic,Vegan Restaurants,Smoothies and Juices,Vegetarian / Vegan Restaurant,Vegetarian,Juice Bar,Vegetarian Restaurants,Healthy,Restaurants    310
# Restaurant,Hotels and motels,American Restaurant,American restaurants,Restaurants                                                                                                                                 308
# ...

# %%
categories_ = df['categories'].value_counts()
categories_
# Out:
# Chinese Restaurant,Restaurant,Cocktails,Vegetarian,Dim Sum,Chinese,Dim Sum Restaurant                                                                                                                             375
# Restaurant,Vegetarian,Indian                                                                                                                                                                                      349
# Restaurant,Coffee Shops,Beverages Wholesale & Manufacturers,Local/Organic,Vegan Restaurants,Smoothies and Juices,Vegetarian / Vegan Restaurant,Vegetarian,Juice Bar,Vegetarian Restaurants,Healthy,Restaurants    310
# Restaurant,Hotels and motels,American Restaurant,American restaurants,Restaurants                                                                                                                                 308
# ...

# %%
categories_.to_frame()
# Out:
#                                                     categories
# Chinese Restaurant,Restaurant,Cocktails,Vegetar...         375
# Restaurant,Vegetarian,Indian                               349
# Restaurant,Coffee Shops,Beverages Wholesale & M...         310
# Restaurant,Hotels and motels,American Restauran...         308
# Chinese Restaurant,Restaurant,Vegetarian / Vega...         265
# ...                                                        ...
# Restaurant,Seafood,Breakfast & Brunch,Bar                    3
# Restaurant,Vegetarian,Healthy                                3
# Restaurant,Vegetarian,Thai,Restaurants                       2
# Restaurant,Breakfast & Brunch,Vegan                          2
# Pizza,New York City,Restaurant,Vegetarian,Kosher             1
#
# [166 rows x 1 columns]

# %%
categories_ = categories_.reset_index()
categories_
# Out:
#                                                  index  categories
# 0    Chinese Restaurant,Restaurant,Cocktails,Vegeta...         375
# 1                         Restaurant,Vegetarian,Indian         349
# 2    Restaurant,Coffee Shops,Beverages Wholesale & ...         310
# 3    Restaurant,Hotels and motels,American Restaura...         308
# 4    Chinese Restaurant,Restaurant,Vegetarian / Veg...         265
# ..                                                 ...         ...
# 161          Restaurant,Seafood,Breakfast & Brunch,Bar           3
# 162                      Restaurant,Vegetarian,Healthy           3
# 163             Restaurant,Vegetarian,Thai,Restaurants           2
# 164                Restaurant,Breakfast & Brunch,Vegan           2
# 165   Pizza,New York City,Restaurant,Vegetarian,Kosher           1
#
# [166 rows x 2 columns]

# %%
df['city'].value_counts()
# Out:
# New York            3395
# Brooklyn            1188
# Portland             316
# Chicago              265
# Charlotte            232
#                     ...
# Escondido              5
# Redmond                4
# Walnut Creek           3
# Santa Rosa Beach       3
# Waltham                1
# Name: city, Length: 81, dtype: int64

# %%
cities_ = df['city'].value_counts()
cities_
# Out:
# New York            3395
# Brooklyn            1188
# Portland             316
# Chicago              265
# Charlotte            232
#                     ...
# Escondido              5
# Redmond                4
# Walnut Creek           3
# Santa Rosa Beach       3
# Waltham                1
# Name: city, Length: 81, dtype: int64

# %%
cities_.to_frame()
# Out:
#                   city
# New York          3395
# Brooklyn          1188
# Portland           316
# Chicago            265
# Charlotte          232
# ...                ...
# Escondido            5
# Redmond              4
# Walnut Creek         3
# Santa Rosa Beach     3
# Waltham              1
#
# [81 rows x 1 columns]

# %%
cities_ = cities_.reset_index()
cities_
# Out:
#                index  city
# 0           New York  3395
# 1           Brooklyn  1188
# 2           Portland   316
# 3            Chicago   265
# 4          Charlotte   232
# ..               ...   ...
# 76         Escondido     5
# 77           Redmond     4
# 78      Walnut Creek     3
# 79  Santa Rosa Beach     3
# 80           Waltham     1
#
# [81 rows x 2 columns]

# %%
df['cuisines'].value_counts()
# Out:
# Vegetarian,Indian                                                                                                       579
# Cocktails,Vegetarian,Dim Sum,Chinese                                                                                    375
# Local/Organic,Vegan Restaurants,Smoothies and Juices,Vegetarian,Healthy                                                 310
# New American,Traditional American,American,Vegetarian Friendly,Gluten Free Options,Vegan Options,Northwest, American    308
# Vegetarian,Dim Sum,Chinese                                                                                              265
#                                                                                                                        ...
# Vegetarian,Californian                                                                                                    5
# ...

# %%
cuisines_ = df['cuisines'].value_counts()
cuisines_
# Out:
# Vegetarian,Indian                                                                                                       579
# Cocktails,Vegetarian,Dim Sum,Chinese                                                                                    375
# Local/Organic,Vegan Restaurants,Smoothies and Juices,Vegetarian,Healthy                                                 310
# New American,Traditional American,American,Vegetarian Friendly,Gluten Free Options,Vegan Options,Northwest, American    308
# Vegetarian,Dim Sum,Chinese                                                                                              265
#                                                                                                                        ...
# Vegetarian,Californian                                                                                                    5
# ...

# %%
cuisines_.to_frame()
# Out:
#                                                     cuisines
# Vegetarian,Indian                                        579
# Cocktails,Vegetarian,Dim Sum,Chinese                     375
# Local/Organic,Vegan Restaurants,Smoothies and J...       310
# New American,Traditional American,American,Vege...       308
# Vegetarian,Dim Sum,Chinese                               265
# ...                                                      ...
# Vegetarian,Californian                                     5
# Vegetarian,Healthy                                         3
# Asian,Thai,Vegetarian Friendly,Asian/Pacific,Fu...         3
# American,Seafood,Wine Bar,Vegetarian Friendly,V...         3
# Pizza,Pizza, Kosher, Vegetarian-Friendly,Vegeta...         1
#
# [149 rows x 1 columns]

# %%
cuisines_ = cuisines_.reset_index()
cuisines_
# Out:
#                                                  index  cuisines
# 0                                    Vegetarian,Indian       579
# 1                 Cocktails,Vegetarian,Dim Sum,Chinese       375
# 2    Local/Organic,Vegan Restaurants,Smoothies and ...       310
# 3    New American,Traditional American,American,Veg...       308
# 4                           Vegetarian,Dim Sum,Chinese       265
# ..                                                 ...       ...
# 144                             Vegetarian,Californian         5
# 145                                 Vegetarian,Healthy         3
# 146  Asian,Thai,Vegetarian Friendly,Asian/Pacific,F...         3
# 147  American,Seafood,Wine Bar,Vegetarian Friendly,...         3
# 148  Pizza,Pizza, Kosher, Vegetarian-Friendly,Veget...         1
#
# [149 rows x 2 columns]

# %%
categories_.columns.to_list()
# Out:
# ['index', 'categories']

# %%
df['province'].value_counts()
# Out:
# NY    5361
# CA    1019
# FL     528
# IL     451
# TX     390
# NC     323
# OR     316
# PA     271
# VA     268
# WA     198
# AZ     166
# MA     144
# UT     100
# MI      95
# MN      75
# NM      66
# NH      50
# WI      47
# NJ      42
# KS      28
# HI      26
# TN      17
# ME       8
# NV       6
# GA       5
# Name: province, dtype: int64

# %%
provinces_ = df['province'].value_counts()

# %%
provinces_
# Out:
# NY    5361
# CA    1019
# FL     528
# IL     451
# TX     390
# NC     323
# OR     316
# PA     271
# VA     268
# WA     198
# AZ     166
# MA     144
# UT     100
# MI      95
# MN      75
# NM      66
# NH      50
# WI      47
# NJ      42
# KS      28
# HI      26
# TN      17
# ME       8
# NV       6
# GA       5
# Name: province, dtype: int64

# %%
provinces_.to_frame()
# Out:
#     province
# NY      5361
# CA      1019
# FL       528
# IL       451
# TX       390
# NC       323
# OR       316
# PA       271
# VA       268
# WA       198
# AZ       166
# MA       144
# UT       100
# MI        95
# MN        75
# NM        66
# NH        50
# WI        47
# NJ        42
# KS        28
# HI        26
# TN        17
# ME         8
# NV         6
# GA         5

# %%
provinces_ = provinces_.reset_index()

# %%
provinces_
# Out:
#    index  province
# 0     NY      5361
# 1     CA      1019
# 2     FL       528
# 3     IL       451
# 4     TX       390
# 5     NC       323
# 6     OR       316
# 7     PA       271
# 8     VA       268
# 9     WA       198
# 10    AZ       166
# 11    MA       144
# 12    UT       100
# 13    MI        95
# 14    MN        75
# 15    NM        66
# 16    NH        50
# 17    WI        47
# 18    NJ        42
# 19    KS        28
# 20    HI        26
# 21    TN        17
# 22    ME         8
# 23    NV         6
# 24    GA         5

# %%
df['menus.category'].value_counts()
# Out:
# Beverages                                                            287
# Appetizers                                                           262
# Sides                                                                196
# Desserts                                                             153
# Salads                                                               127
#                                                                     ...
# Meat Entries                                                           1
# Fruit Smoothies                                                        1
# Japanese Dinner Specials  Panko Breaded or Marinated ampamp Fried      1
# Espresso Signature Drinks                                              1
# Special Lunch Boxes to Go                                              1
# Name: menus.category, Length: 818, dtype: int64

# %%
menucategories_ = df['menus.category'].value_counts()
menucategories_
# Out:
# Beverages                                                            287
# Appetizers                                                           262
# Sides                                                                196
# Desserts                                                             153
# Salads                                                               127
#                                                                     ...
# Meat Entries                                                           1
# Fruit Smoothies                                                        1
# Japanese Dinner Specials  Panko Breaded or Marinated ampamp Fried      1
# Espresso Signature Drinks                                              1
# Special Lunch Boxes to Go                                              1
# Name: menus.category, Length: 818, dtype: int64

# %%
menucategories_
# Out:
# Beverages                                                            287
# Appetizers                                                           262
# Sides                                                                196
# Desserts                                                             153
# Salads                                                               127
#                                                                     ...
# Meat Entries                                                           1
# Fruit Smoothies                                                        1
# Japanese Dinner Specials  Panko Breaded or Marinated ampamp Fried      1
# Espresso Signature Drinks                                              1
# Special Lunch Boxes to Go                                              1
# Name: menus.category, Length: 818, dtype: int64

# %%
menucategories_.to_frame()
# Out:
#                                                     menus.category
# Beverages                                                      287
# Appetizers                                                     262
# Sides                                                          196
# Desserts                                                       153
# Salads                                                         127
# ...                                                            ...
# Meat Entries                                                     1
# Fruit Smoothies                                                  1
# Japanese Dinner Specials  Panko Breaded or Mari...               1
# Espresso Signature Drinks                                        1
# Special Lunch Boxes to Go                                        1
#
# [818 rows x 1 columns]

# %%
menucategories_ = menucategories_.reset_index()

# %%
menucategories_
# Out:
#                                                  index  menus.category
# 0                                            Beverages             287
# 1                                           Appetizers             262
# 2                                                Sides             196
# 3                                             Desserts             153
# 4                                               Salads             127
# ..                                                 ...             ...
# 813                                       Meat Entries               1
# 814                                    Fruit Smoothies               1
# 815  Japanese Dinner Specials  Panko Breaded or Mar...               1
# 816                          Espresso Signature Drinks               1
# 817                          Special Lunch Boxes to Go               1
#
# [818 rows x 2 columns]

# %% [markdown]
# ## Now let's dive into some descriptive statistics and analysis of our data

# %%
df['categories'].describe()
# Out:
# count                                                 10000
# unique                                                  166
# top       Chinese Restaurant,Restaurant,Cocktails,Vegeta...
# freq                                                    375
# Name: categories, dtype: object

# %%
df['categories'].value_counts()
# Out:
# Chinese Restaurant,Restaurant,Cocktails,Vegetarian,Dim Sum,Chinese,Dim Sum Restaurant                                                                                                                             375
# Restaurant,Vegetarian,Indian                                                                                                                                                                                      349
# Restaurant,Coffee Shops,Beverages Wholesale & Manufacturers,Local/Organic,Vegan Restaurants,Smoothies and Juices,Vegetarian / Vegan Restaurant,Vegetarian,Juice Bar,Vegetarian Restaurants,Healthy,Restaurants    310
# Restaurant,Hotels and motels,American Restaurant,American restaurants,Restaurants                                                                                                                                 308
# ...

# %%
df['categories'].value_counts().head(10)
# Out:
# Chinese Restaurant,Restaurant,Cocktails,Vegetarian,Dim Sum,Chinese,Dim Sum Restaurant                                                                                                                             375
# Restaurant,Vegetarian,Indian                                                                                                                                                                                      349
# Restaurant,Coffee Shops,Beverages Wholesale & Manufacturers,Local/Organic,Vegan Restaurants,Smoothies and Juices,Vegetarian / Vegan Restaurant,Vegetarian,Juice Bar,Vegetarian Restaurants,Healthy,Restaurants    310
# Restaurant,Hotels and motels,American Restaurant,American restaurants,Restaurants                                                                                                                                 308
# ...

# %%
df['categories'].min()
# Out:
# 'American (New),Restaurant,Coffee Shop,Coffee and Tea,Coffeehouses,Coffee Tea Shops,Restaurants'

# %%
df['categories'].max()
# Out:
# 'Vietnamese Restaurant Sunset Park,Restaurant,Vietnamese Restaurant,Vegetarian,Vietnamese'

# %%
categories_
# Out:
#                                                  index  categories
# 0    Chinese Restaurant,Restaurant,Cocktails,Vegeta...         375
# 1                         Restaurant,Vegetarian,Indian         349
# 2    Restaurant,Coffee Shops,Beverages Wholesale & ...         310
# 3    Restaurant,Hotels and motels,American Restaura...         308
# 4    Chinese Restaurant,Restaurant,Vegetarian / Veg...         265
# ..                                                 ...         ...
# 161          Restaurant,Seafood,Breakfast & Brunch,Bar           3
# 162                      Restaurant,Vegetarian,Healthy           3
# 163             Restaurant,Vegetarian,Thai,Restaurants           2
# 164                Restaurant,Breakfast & Brunch,Vegan           2
# 165   Pizza,New York City,Restaurant,Vegetarian,Kosher           1
#
# [166 rows x 2 columns]

# %%
top10categories = df['categories'].value_counts()[:10]
top10categories.plot(kind='barh',figsize=(10,8))
plt.title('All Time Categories')
# Out:
# Text(0.5, 1.0, 'All Time Categories')

# %% [markdown]
# #### Created through Python, the visualization demonstrates a graph s that represents the categories and the amount ot categories

# %% [markdown]
# #### There seems to many categories in categories, so let's break it down

# %%
df = df.assign(categories=df['categories'].str.split(',')).explode('categories')

# %%
df
# Out:
#                         id             dateAdded           dateUpdated  \
# 0     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 0     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 0     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 0     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 0     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# ...                    ...                   ...                   ...
# 9999  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9999  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9999  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9999  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9999  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
#
#                  address                     categories  \
# 0     1045 San Pablo Ave                     Restaurant
# ...

# %% [markdown]
# ### Let's look at the frequency of Chinese places

# %%
df.loc[df['categories'].str.contains('Chinese')]
# Out:
#                         id             dateAdded           dateUpdated  \
# 916   AVzA19T-FcQ3k02bBX1q  2017-06-19T14:53:09Z  2018-07-19T21:05:13Z
# 916   AVzA19T-FcQ3k02bBX1q  2017-06-19T14:53:09Z  2018-07-19T21:05:13Z
# 917   AVzA19T-FcQ3k02bBX1q  2017-06-19T14:53:09Z  2018-07-19T21:05:13Z
# 917   AVzA19T-FcQ3k02bBX1q  2017-06-19T14:53:09Z  2018-07-19T21:05:13Z
# 918   AVzA19T-FcQ3k02bBX1q  2017-06-19T14:53:09Z  2018-07-19T21:05:13Z
# ...                    ...                   ...                   ...
# 9825  AV8wUvqERxPSIh2RltEQ  2017-10-18T16:27:41Z  2018-02-02T16:06:33Z
# 9826  AV8wUvqERxPSIh2RltEQ  2017-10-18T16:27:41Z  2018-02-02T16:06:33Z
# 9827  AV8wUvqERxPSIh2RltEQ  2017-10-18T16:27:41Z  2018-02-02T16:06:33Z
# 9828  AV8wUvqERxPSIh2RltEQ  2017-10-18T16:27:41Z  2018-02-02T16:06:33Z
# 9829  AV8wUvqERxPSIh2RltEQ  2017-10-18T16:27:41Z  2018-02-02T16:06:33Z
#
#                address          categories              primaryCategories  \
# ...

# %% [markdown]
# #### This data represents the term Chinese in our analysis, for example we can  see which states offer Chinese food specifically

# %%
cities_.columns.to_list()
# Out:
# ['city', 'count']

# %%
cities_.columns = ['city', 'count']

# %%
cities_
# Out:
#                 city  count
# 0           New York   3395
# 1           Brooklyn   1188
# 2           Portland    316
# 3            Chicago    265
# 4          Charlotte    232
# ..               ...    ...
# 76         Escondido      5
# 77           Redmond      4
# 78      Walnut Creek      3
# 79  Santa Rosa Beach      3
# 80           Waltham      1
#
# [81 rows x 2 columns]

# %%
df['city'].describe()
# Out:
# count        61854
# unique          81
# top       New York
# freq         20845
# Name: city, dtype: object

# %%
df['city'].value_counts()
# Out:
# New York            20845
# Brooklyn             6779
# Houston              2190
# Miami                1860
# Hollywood            1848
#                     ...
# Atlanta                15
# Walnut Creek           12
# Santa Rosa Beach       12
# Redmond                 8
# Waltham                 2
# Name: city, Length: 81, dtype: int64

# %%
df['city'].value_counts().head(10)
# Out:
# New York         20845
# Brooklyn          6779
# Houston           2190
# Miami             1860
# Hollywood         1848
# Beverly Hills     1833
# Chicago           1697
# Encino            1677
# Portland          1556
# Pittsburgh        1362
# Name: city, dtype: int64

# %%
df['city'].min()
# Out:
# 'Albany'

# %%
df['city'].max()
# Out:
# 'Woodside'

# %%
top10vegancities = df['city'].value_counts()[:10]
top10vegancities.plot(kind='bar',figsize=(10,8))
plt.title('All Time Vegan Cities')
# Out:
# Text(0.5, 1.0, 'All Time Vegan Cities')

# %% [markdown]
# #### Created through Python, the visualization demonstrates a graph s that represents the cities that offer plant based options

# %%
cuisines_.columns.to_list()
# Out:
# ['index', 'cuisines']

# %%
cuisines_.columns = ['cuisine', 'count']

# %%
cuisines_
# Out:
#                                                cuisine  count
# 0                                    Vegetarian,Indian    579
# 1                 Cocktails,Vegetarian,Dim Sum,Chinese    375
# 2    Local/Organic,Vegan Restaurants,Smoothies and ...    310
# 3    New American,Traditional American,American,Veg...    308
# 4                           Vegetarian,Dim Sum,Chinese    265
# ..                                                 ...    ...
# 144                             Vegetarian,Californian      5
# 145                                 Vegetarian,Healthy      3
# 146  Asian,Thai,Vegetarian Friendly,Asian/Pacific,F...      3
# 147  American,Seafood,Wine Bar,Vegetarian Friendly,...      3
# 148  Pizza,Pizza, Kosher, Vegetarian-Friendly,Veget...      1
#
# [149 rows x 2 columns]

# %%
df['cuisines'].describe()
# Out:
# count                                                 61854
# unique                                                  149
# top       Local/Organic,Vegan Restaurants,Smoothies and ...
# freq                                                   3720
# Name: cuisines, dtype: object

# %%
df['cuisines'].value_counts()
# Out:
# Local/Organic,Vegan Restaurants,Smoothies and Juices,Vegetarian,Healthy                                           3720
# Cocktails,Vegetarian,Dim Sum,Chinese                                                                              2625
# Vegetarian,Indian                                                                                                 2468
# Vegetarian,Dim Sum,Chinese                                                                                        1855
# Greek,Seafood,Mediterranean,Vegetarian,Mediterranean Restaurants                                                  1848
#                                                                                                                   ...
# Ethiopian,Vegetarian                                                                                                14
# Asian,Thai,Vegetarian Friendly,Asian/Pacific,Fusion                                                                 12
# ...

# %%
df['cuisines'].value_counts().head(10)
# Out:
# Local/Organic,Vegan Restaurants,Smoothies and Juices,Vegetarian,Healthy                                                 3720
# Cocktails,Vegetarian,Dim Sum,Chinese                                                                                    2625
# Vegetarian,Indian                                                                                                       2468
# Vegetarian,Dim Sum,Chinese                                                                                              1855
# Greek,Seafood,Mediterranean,Vegetarian,Mediterranean Restaurants                                                        1848
# Ice Cream and Desserts,Breakfast and Brunch,Coffee and Tea,Vegan,Vegetarian                                             1833
# Local/Organic,Smoothies and Juices,Vegetarian,Kosher,Healthy,Vegan                                                      1790
# ...

# %%
df['cuisines'].min()
# Out:
# 'American (New),Local/Organic,Vegetarian'

# %%
df['cuisines'].max()
# Out:
# 'Vegetarian,Vietnamese'

# %%
top10cuisines = df['cuisines'].value_counts()[:10]
top10cuisines.plot(kind='barh',figsize=(10,8))
plt.title('All Time Cuisines')
# Out:
# Text(0.5, 1.0, 'All Time Cuisines')

# %% [markdown]
# #### Created through Python, the visualization demonstrates a graph that represents the types of vegetarian and vegan cuisines

# %%
menucategories_.columns.to_list()
# Out:
# ['index', 'menus.category']

# %%
menucategories_.columns = ['menuname', 'count']

# %%
menucategories_
# Out:
#                                               menuname  count
# 0                                            Beverages    287
# 1                                           Appetizers    262
# 2                                                Sides    196
# 3                                             Desserts    153
# 4                                               Salads    127
# ..                                                 ...    ...
# 813                                       Meat Entries      1
# 814                                    Fruit Smoothies      1
# 815  Japanese Dinner Specials  Panko Breaded or Mar...      1
# 816                          Espresso Signature Drinks      1
# 817                          Special Lunch Boxes to Go      1
#
# [818 rows x 2 columns]

# %%
df['menus.name'].describe()
# Out:
# count      61854
# unique      7426
# top       Coffee
# freq         151
# Name: menus.name, dtype: object

# %%
df['menus.name'].value_counts()
# Out:
# Coffee                                   151
# Soda                                     141
# Cappuccino                               131
# Hummus                                   124
# Espresso                                 115
#                                         ...
# Sodasampcomma Iced Teaampcomma Coffee      2
# Any Three Tamales                          2
# Mushroom Poblano                           2
# Side Of Sour Cream                         2
# Sweet ampamp Sour Eggplant                 2
# Name: menus.name, Length: 7426, dtype: int64

# %%
df['menus.name'].value_counts().head(10)
# Out:
# Coffee           151
# Soda             141
# Cappuccino       131
# Hummus           124
# Espresso         115
# Greek Salad       98
# Avocado           98
# Lemonade          97
# Americano         96
# Bottled Water     89
# Name: menus.name, dtype: int64

# %%
df['menus.name'].min()
# Out:
# '"Poptart"'

# %%
df['menus.name'].max()
# Out:
# 'oz Zinger Juice'

# %%
top10menus = df['menus.name'].value_counts()[:10]
top10menus.plot(kind='barh',figsize=(10,8))
plt.title('All Time Menu Names')
# Out:
# Text(0.5, 1.0, 'All Time Menu Names')

# %% [markdown]
# #### Created through Python, the visualization demonstrates a graph that represents the types of menu items offered at these restaurants. We can see it is mostly beverages that are most common among the restaurants with the exception of avacados.

# %%
provinces_.columns.to_list()
# Out:
# ['index', 'province']

# %%
provinces_.columns = ['province', 'count']

# %%
provinces_
# Out:
#    province  count
# 0        NY   5361
# 1        CA   1019
# 2        FL    528
# 3        IL    451
# 4        TX    390
# 5        NC    323
# 6        OR    316
# 7        PA    271
# 8        VA    268
# 9        WA    198
# 10       AZ    166
# 11       MA    144
# 12       UT    100
# 13       MI     95
# 14       MN     75
# 15       NM     66
# 16       NH     50
# 17       WI     47
# 18       NJ     42
# 19       KS     28
# 20       HI     26
# 21       TN     17
# 22       ME      8
# 23       NV      6
# 24       GA      5

# %%
df['province'].describe()
# Out:
# count     10000
# unique       25
# top          NY
# freq       5361
# Name: province, dtype: object

# %%
df['province'].value_counts()
# Out:
# NY    5361
# CA    1019
# FL     528
# IL     451
# TX     390
# NC     323
# OR     316
# PA     271
# VA     268
# WA     198
# AZ     166
# MA     144
# UT     100
# MI      95
# MN      75
# NM      66
# NH      50
# WI      47
# NJ      42
# KS      28
# HI      26
# TN      17
# ME       8
# NV       6
# GA       5
# Name: province, dtype: int64

# %%
df['province'].value_counts().head(10)
# Out:
# NY    5361
# CA    1019
# FL     528
# IL     451
# TX     390
# NC     323
# OR     316
# PA     271
# VA     268
# WA     198
# Name: province, dtype: int64

# %%
df['province'].min()
# Out:
# 'AZ'

# %%
df['province'].max()
# Out:
# 'WI'

# %%
top10states = df['province'].value_counts()[:10]
top10states.plot(kind='bar',figsize=(10,8))
plt.title('All Time Friendly Vegan/Vegetarian States')
# Out:
# Text(0.5, 1.0, 'All Time Friendly Vegan/Vegetarian States')

# %% [markdown]
# #### Created through Python, the visualization demonstrates a graph that represents the states with vegan and vegetarian options

# %%
df['menus.amountMin'].describe()
# Out:
# count    61854.000000
# mean        13.229520
# std         41.656333
# min          0.000000
# 25%          4.000000
# 50%          7.000000
# 75%         11.000000
# max       2500.000000
# Name: menus.amountMin, dtype: float64

# %%
df['menus.amountMax'].describe()
# Out:
# count    61854.000000
# mean        13.324103
# std         41.661644
# min          0.000000
# 25%          4.000000
# 50%          7.000000
# 75%         11.000000
# max       2500.000000
# Name: menus.amountMax, dtype: float64

# %% [markdown]
# ## Let's organize the data once again by using relevant columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       10000 non-null  object
#  1   dateAdded                10000 non-null  object
#  2   dateUpdated              10000 non-null  object
#  3   address                  10000 non-null  object
#  4   categories               10000 non-null  object
#  5   primaryCategories        10000 non-null  object
#  6   city                     10000 non-null  object
#  7   claimed                  689 non-null    object
#  8   country                  10000 non-null  object
#  9   cuisines                 10000 non-null  object
#  10  descriptions.dateSeen    0 non-null      float64
#  11  descriptions.sourceURLs  0 non-null      float64
#  12  descriptions.value       0 non-null      float64
#  13  facebookPageURL          937 non-null    object
# ...

# %% [markdown]
# Here I picked columns that are most relevant which is location and restaurant types.

# %%
df[['categories','city','country','cuisines','province','latitude','longitude']]
# Out:
#                                              categories     city country  \
# 0     Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...   Albany      US
# 1     Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...   Albany      US
# 2     Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...   Albany      US
# 3     Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...   Albany      US
# 4     Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...   Albany      US
# ...                                                 ...      ...     ...
# 9995  Vegetarian / Vegan Restaurant,Restaurant,Medit...  Phoenix      US
# 9996  Vegetarian / Vegan Restaurant,Restaurant,Medit...  Phoenix      US
# 9997  Vegetarian / Vegan Restaurant,Restaurant,Medit...  Phoenix      US
# 9998  Vegetarian / Vegan Restaurant,Restaurant,Medit...  Phoenix      US
# 9999  Vegetarian / Vegan Restaurant,Restaurant,Medit...  Phoenix      US
#
#                                              cuisines province   latitude  \
# ...

# %%
desired_columns = ['categories','city','country','cuisines','province','latitude','longitude']

# %%
df[desired_columns]
# Out:
#                                              categories     city country  \
# 0     Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...   Albany      US
# 1     Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...   Albany      US
# 2     Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...   Albany      US
# 3     Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...   Albany      US
# 4     Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...   Albany      US
# ...                                                 ...      ...     ...
# 9995  Vegetarian / Vegan Restaurant,Restaurant,Medit...  Phoenix      US
# 9996  Vegetarian / Vegan Restaurant,Restaurant,Medit...  Phoenix      US
# 9997  Vegetarian / Vegan Restaurant,Restaurant,Medit...  Phoenix      US
# 9998  Vegetarian / Vegan Restaurant,Restaurant,Medit...  Phoenix      US
# 9999  Vegetarian / Vegan Restaurant,Restaurant,Medit...  Phoenix      US
#
#                                              cuisines province   latitude  \
# ...

# %%
df_trimmed = df[desired_columns].copy()
df_trimmed
# Out:
#                                              categories     city country  \
# 0     Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...   Albany      US
# 1     Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...   Albany      US
# 2     Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...   Albany      US
# 3     Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...   Albany      US
# 4     Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...   Albany      US
# ...                                                 ...      ...     ...
# 9995  Vegetarian / Vegan Restaurant,Restaurant,Medit...  Phoenix      US
# 9996  Vegetarian / Vegan Restaurant,Restaurant,Medit...  Phoenix      US
# 9997  Vegetarian / Vegan Restaurant,Restaurant,Medit...  Phoenix      US
# 9998  Vegetarian / Vegan Restaurant,Restaurant,Medit...  Phoenix      US
# 9999  Vegetarian / Vegan Restaurant,Restaurant,Medit...  Phoenix      US
#
#                                              cuisines province   latitude  \
# ...

# %% [markdown]
# #### The city of Chicago has over 265 options of vegan/vegetarian options

# %%
df_trimmed.loc[df_trimmed['city'] == 'Chicago']
# Out:
#                                              categories     city country  \
# 4734  Restaurant,Mediterranean Restaurants,Vegetaria...  Chicago      US
# 4735  Restaurant,Mediterranean Restaurants,Vegetaria...  Chicago      US
# 4736  Restaurant,Mediterranean Restaurants,Vegetaria...  Chicago      US
# 4737  Restaurant,Mediterranean Restaurants,Vegetaria...  Chicago      US
# 4738  Restaurant,Mediterranean Restaurants,Vegetaria...  Chicago      US
# ...                                                 ...      ...     ...
# 8442  Bars Clubs,Restaurant,Italian Restaurant,Halls...  Chicago      US
# 8443  Bars Clubs,Restaurant,Italian Restaurant,Halls...  Chicago      US
# 8444  Bars Clubs,Restaurant,Italian Restaurant,Halls...  Chicago      US
# 8445  Bars Clubs,Restaurant,Italian Restaurant,Halls...  Chicago      US
# 8446  Bars Clubs,Restaurant,Italian Restaurant,Halls...  Chicago      US
#
#                                                cuisines province   latitude  \
# ...

# %%
df_trimmed.loc[df_trimmed['city'] == 'Chicago'].value_counts()
# Out:
# categories                                                                                                           city     country  cuisines                                                                    province  latitude   longitude
# Bars Clubs,Restaurant,Italian Restaurant,Halls Auditoriums,Bars Pubs,Italian Restaurant Near North Side,Restaurants  Chicago  US       Italian,American,Bar,Vegetarian Friendly,Gluten Free Options,Vegan Options  IL        41.889212  -87.630268    173
# Restaurant,Vegetarian / Vegan Restaurant,Vegetarian,Restaurants                                                      Chicago  US       Vegetarian,Caterers                                                         IL        41.896114  -87.664651     23
# Restaurant,Mediterranean Restaurants,Vegetarian Restaurants,Restaurants,Middle Eastern Restaurants                   Chicago  US       Mediterranean,Vegetarian Restaurants                                        IL        41.983650  -87.668717     20
# ...

# %% [markdown]
# #### In comparison, the city of New York has over 3000 vegan/vegetarian options

# %%
df_trimmed.loc[df_trimmed['city'] == 'New York']
# Out:
#                 categories      city country  \
# 37              Restaurant  New York      US
# 37              Juice Bars  New York      US
# 37    Smoothies and Juices  New York      US
# 37              Vegetarian  New York      US
# 37        Beverages Retail  New York      US
# ...                    ...       ...     ...
# 9850                Salads  New York      US
# 9850            Vegetarian  New York      US
# 9851            Restaurant  New York      US
# 9851                Salads  New York      US
# 9851            Vegetarian  New York      US
#
#                                      cuisines   latitude  longitude
# 37    Smoothies and Juices,Vegetarian,Healthy  40.785469 -73.979105
# 37    Smoothies and Juices,Vegetarian,Healthy  40.785469 -73.979105
# 37    Smoothies and Juices,Vegetarian,Healthy  40.785469 -73.979105
# 37    Smoothies and Juices,Vegetarian,Healthy  40.785469 -73.979105
# 37    Smoothies and Juices,Vegetarian,Healthy  40.785469 -73.979105
# ...

# %%
df_trimmed.loc[df_trimmed['city'] == 'New York'].value_counts()
# Out:
# categories                                                                                                                                                                                                      city      country  cuisines                                                                 province  latitude   longitude
# Chinese Restaurant,Restaurant,Cocktails,Vegetarian,Dim Sum,Chinese,Dim Sum Restaurant                                                                                                                           New York  US       Cocktails,Vegetarian,Dim Sum,Chinese                                     NY        40.758343  -73.990152    375
# ...

# %% [markdown]
# ## Let's map the data using the longitude and latitude values

# %%
import matplotlib.pyplot as plt
plt.scatter(x=df['longitude'], y=df['latitude'])
plt.show()

# %%
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# ### Here's is a glimpse of the data from the country perspective

# %%
df = pd.read_csv("Vegetarian_and_Vegan_Restaurants.csv", delimiter=',', skiprows=0, low_memory=False)

geometry = [Point(xy) for xy in zip(df['longitude'], df['latitude'])]
gdf = GeoDataFrame(df, geometry=geometry)   

#this is a simple map that goes with geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=15)
# Out:
# <AxesSubplot:>

# %%
# Grab low resolution world file
world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
world = world.set_index("iso_a3")

world.head()
# Out:
#           pop_est      continent                      name  gdp_md_est  \
# iso_a3
# FJI        920938        Oceania                      Fiji      8374.0
# TZA      53950935         Africa                  Tanzania    150600.0
# ESH        603253         Africa                 W. Sahara       906.5
# CAN      35623680  North America                    Canada   1674000.0
# USA     326625791  North America  United States of America  18560000.0
#
#                                                  geometry
# iso_a3
# FJI     MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# TZA     POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# ESH     POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# CAN     MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# USA     MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
fig, gax = plt.subplots(figsize=(10,10))

# By only plotting rows in which the continent is 'South America' we only plot SA.
world.query("continent == 'North America'").plot(ax=gax, edgecolor='black',color='white')

# By the way, if you haven't read the book 'longitude' by Dava Sobel, you should...
gax.set_xlabel('longitude')
gax.set_ylabel('latitude')

gax.spines['top'].set_visible(False)
gax.spines['right'].set_visible(False)

plt.show()

# %%
# Step 3: Plot the cities onto the map
# We mostly use the code from before --- we still want the country borders plotted --- and we
# add a command to plot the cities
fig, gax = plt.subplots(figsize=(10,10))

# By only plotting rows in which the continent is 'South America' we only plot, well,
# South America.
world.query("continent == 'North America'").plot(ax = gax, edgecolor='black', color='white')

# This plot the cities. It's the same syntax, but we are plotting from a different GeoDataFrame.
# I want the cities as pale red dots.
gdf.plot(ax=gax, color='red', alpha = 0.5)

gax.set_xlabel('longitude')
gax.set_ylabel('latitude')
gax.set_title('North America')

gax.spines['top'].set_visible(False)
gax.spines['right'].set_visible(False)

plt.show()

# %% [markdown]
# ### Here is a better look !

# %% [markdown]
# #### Discussion

# %% [markdown]
# Based on the following visualizations, veganism and vegetarianism is common in the United States. Given the range of categories from the data set, we can see that the most common cuisine are Chinese Restaurant,Restaurant,Cocktails,Vegetarian,Dim Sum,Chinese,Dim Sum Restaurant. This has a frequency of 375 times for the data. This reveals that the most popular category for a plant based diet is Asian. This is interesting given that Americans tend to cater to American foods , however it is known that Asian foods are vegan friendly. It is also interesting how American vegan/vegetarian food is not popular.  From our data set we have a wide range of categories ranging from smoothies, Thai food, seafood etc. Since Chinese food is widely popular, we can imply that Chinese foods are the most vegan/vegetarian friendly and more widely available in the United States than any other category.

# %% [markdown]
# We can also visualize the cities that offer plant based diets. New York is the leading city to offer vegan/vegetarian options. Over 3000 restaurants in the metropolitan area offer unique menu items that cater to individuals following this diet. The second leading city is Brooklyn, which is also located in the state of New York.   The city with the least amount of options is Waltham which is a city in the state of Massachusetts. The small city of Santa Rosa beach located in Florida also offers the least amount of options which has a number of only 3 restaurants with such options.  The cities with the most options are located in the state of New York and California. As for cuisines, the most popular is Local/Organic, smoothies, vegetarian and vegan options. This cuisine had the highest frequency and the lowest was American (New),Vegetarian,Coffee and Tea,Health Food,Vegan.

# %% [markdown]
# As for the menu options, there was not much unique data revealed. Given that we are working with a large amount of data, the menu items were very different from one another. There were no common frequencies at all. The data was organized by restaurant name alphabetically and the menu item offered. For example, we can see that the restaurant Poptart offers watermelon salads and Aloo Paratha offers zeera rice. In general, each restaurant offered different menus and options. However, when we graphed the menu items with a bar graph the most frequent item was soda. The graph revealed that soda, coffee, cappuccinos, and dressings such as hummus were the most popular and frequent. Evidently, these drinks are popular in America and offered in these restaurants. They are the food items universally offered in such spaces. Interestingly, we can also see that avocado toast and greek salads were menu items most frequently offered in the restaurants. These were the only food dishes offered in the restaurants besides the drinks. I also analyzed the statistical data regarding the menu item prices. The average amount of menu item prices was around 13 United States dollars. This is relatively unique in the sense that vegan foods are known to be more costly than fast food prices in America.

# %% [markdown]
# In terms of geographic locations, the state with the most popular and widely plant based options is New York, California, Florida, and Texas. This is interesting given that veganism is commonly associated with West Coast culture. However based on our analysis, plant based diets are offered in several parts of the states. It is important to note that most of the restaurants are located in large cities where the demand for these options are significantly higher than rural areas. For example, the state of Georgia and Nevada are the areas with the least amount of restaurants that offer these food items. States in the Southern part of the United States such as Kansas offer the least amount of options. Texas, is the exception of this. The city of Houston was one of the most popular cities that offered several restaurants with plant based menu items.

# %% [markdown]
# #### Conclusion

# %% [markdown]
# In conclusion, vegan and vegetarian options are widely available in metropolitan areas in the United States. Based on our map of the data, there is a distribution of restaurants across the country however it is not all equal. The west coast and east coast visually have more restaurants that offer plant based options. This is evident through the many locations of these places in New York and California. We can conclude that these areas are the most vegan and vegetarian friendly than any other states in the country. The areas with the least amount of options are the northern part of the States such as Montana, Nebraska, Wyoming etc. With our data we can only pinpoint which areas offer plant based options and what options are available. The reasonings behind these choices depend on the population, culture, and markets of these areas. The state of California for example, is one of the most diverse states in America. Plant based food is widely available in this area given the demographics and interests of businesses and corporations in such cities. In this case, our data revealed that New York offers the most plant based diets. However, it is important to note that this data set is from the year 2018. The numbers have no doubt skyrocketed given the number of new plant based foods appearing at our grocery stores and local restaurants. From our data set however, we can analyze the unique number of menu items, cuisines, and categories of food we can choose from. Over time, menu items are adapting to plant based options and becoming more creative than ever. As a vegan, these choices are important to our lifestyle and promote inclusivity.
